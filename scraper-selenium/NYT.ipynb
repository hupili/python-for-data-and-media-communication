# %% [markdown]
# Highlights:
#
# - This notebook shows a "human-in-the-loop" approach.
# - Ask the human operator to click the "show more button", when asked indicated by this notebook
# - You only need to click this button once, and the script will execute forever, scrolling to the end
#
# **NOTE**:
#
# - If your browser screen is small, most likely when you opened developer tool, NYT site will think your browser to be a mobile one.
# - In the mobile browser mode, "show more" button will appear repeated. They want to save traffic. When you do the following experiments, you may want to work on a desktop with a reasonably large screen. So this "human in the loop" can actually work.

# %% [markdown]
# ## Initial setup

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2018-11-08 01:55:49.607645

# %%
url = 'https://www.nytimes.com/section/world'

# %%
from selenium import webdriver
import time
browser = webdriver.Chrome()
browser.get(url)

# %%
browser.find_elements_by_css_selector('h2.headline')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-13")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-28")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-40")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-43")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-47")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-60")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-61")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="572679d654becff5225f83de866f76e3", element="0.7355895603345244-64")>]

# %%
data = []
for s in browser.find_elements_by_css_selector('div.story-body'):
    a = s.find_element_by_css_selector('h2.headline')
    headline = a.text
    try:
        url = a.find_element_by_css_selector('a').get_attribute('href')
    except:
        url = None
    try:
        dt = s.find_element_by_css_selector('time').get_attribute('datetime')
    except:
        dt = None
    data.append({
        'headline': headline,
        'url': url,
        'datetime': dt
    })

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       datetime                                           headline  \
# 0   1541520747  Erdogan Champions Khashoggi While Trampling Jo...
# 1   1541587767  Cameroon Students Have Been Released, Official...
# 2   1541584807  Dry Spell: Canada Runs Low on Legal Marijuana ...
# 3   1541529385  As Famine Looms in Yemen, Saudi-Led Coalition ...
# 4   1541474477  The Nauru Experience: Zero-Tolerance Immigrati...
# 5   1541580343  Philippine Lawyer Who Resisted Duterte’s Drug ...
# 6   1541536215  Ex-Guard, 94, at Nazi Camp Is Tried in German ...
# 7   1541521423  A ‘Legacy of Terror’: ISIS Left More Than 200 ...
# 8   1541517537  Facebook Admits It Was Used to Incite Violence...
# 9   1541513702  Taliban Pummel Security Forces Across Afghanistan
# 10  1541559813  Geoffrey Rush’s Defamation Trial Becomes a #Me...
# 11  1541496540  Suicides Among Japanese Children Reach Highest...
# 12  1541498407  Fight Against Last Vestige of ISIS in Syria St...
# 13  1541498990  What Do North Korean Gymnastics Say About Kim ...
# 14  1541404749  Bare Knuckle Bouts in Madagascar? ‘It Is About...
# 15  1541318347
# 16  1541094086
# 17  1540890009
# 18  1540544583
# 19  1537462861  China’s Sea Control Is a Done Deal, ‘Short of ...
# 20  1536412675
# 21  1535517728
# 22  1534790009
# 23  1534095377
# 24        None  Death Toll From Collapsed Buildings in Marseil...
# 25        None  Italy Loosens Gun Laws as Matteo Salvini Polis...
# 26        None  Indonesia Looks Into Possible Sensor Problems ...
# 27        None  Australia Likely to Block Hong Kong Company’s ...
# 28        None  The Election Showed a Divided Country. Investo...
# 29        None  Pompeo Meeting With North Korean Diplomat Post...
# ..         ...                                                ...
# 34        None
# 35        None
# 36        None
# 37        None
# 38        None
# 39        None
# 40        None
# 41        None
# 42        None
# 43        None
# 44        None
# 45        None
# 46        None
# 47        None
# 48        None
# 49        None
# 50        None
# 51        None
# 52        None
# 53        None
# 54        None
# 55        None
# 56        None
# 57        None
# 58        None
# 59        None
# 60        None
# 61        None
# 62        None
# 63        None
#
#                                                   url
# 0   https://www.nytimes.com/2018/11/06/world/europ...
# 1   https://www.nytimes.com/2018/11/07/world/afric...
# 2   https://www.nytimes.com/2018/11/07/world/canad...
# 3   https://www.nytimes.com/2018/11/06/world/middl...
# 4   https://www.nytimes.com/2018/11/05/world/austr...
# 5   https://www.nytimes.com/2018/11/07/world/asia/...
# 6   https://www.nytimes.com/2018/11/06/world/europ...
# 7   https://www.nytimes.com/2018/11/06/world/middl...
# 8   https://www.nytimes.com/2018/11/06/technology/...
# 9   https://www.nytimes.com/2018/11/06/world/asia/...
# 10  https://www.nytimes.com/2018/11/06/world/austr...
# 11  https://www.nytimes.com/2018/11/06/world/asia/...
# 12  https://www.nytimes.com/2018/11/06/world/middl...
# 13  https://www.nytimes.com/2018/11/06/world/asia/...
# 14  https://www.nytimes.com/2018/11/05/world/afric...
# 15  https://www.nytimes.com/2018/11/04/world/ameri...
# 16  https://www.nytimes.com/2018/11/01/world/europ...
# 17  https://www.nytimes.com/2018/10/30/world/europ...
# 18  https://www.nytimes.com/video/world/americas/1...
# 19  https://www.nytimes.com/2018/09/20/world/asia/...
# 20  https://www.nytimes.com/2018/09/08/world/asia/...
# 21  https://www.nytimes.com/2018/08/29/world/asia/...
# 22  https://www.nytimes.com/2018/08/20/world/asia/...
# 23  https://www.nytimes.com/2018/08/12/business/ch...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# ..                                                ...
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                               None
# 61                                               None
# 62                                               None
# 63                                               None
#
# [64 rows x 3 columns]

# %%
len(df)
# Out:
# 64

# %% [markdown]
# ## Human in the loop

# %% [markdown]
# Of course, I can use selenium to click the "show more" button. However, this operation is one off. Once we click "show more" for the first time, we don't have repeatedly click it. We only need to scroll. We can use human to solve the *onf-off* problem (show more) and hand over the repeated tasks to machines (scroll/ scrape).
#
# Note that we only have 64 entries above. I'm going to scrape far more entries than that.

# %% [markdown]
# ## Machine takes over and scroll down

# %%
import time

# %%
for i in range(1, 30):
    browser.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    time.sleep(1)

# %% [markdown]
# The scraping codes are the same as before

# %%
data = []
for s in browser.find_elements_by_css_selector('div.story-body'):
    a = s.find_element_by_css_selector('h2.headline')
    headline = a.text
    try:
        url = a.find_element_by_css_selector('a').get_attribute('href')
    except:
        url = None
    try:
        dt = s.find_element_by_css_selector('time').get_attribute('datetime')
    except:
        dt = None
    data.append({
        'headline': headline,
        'url': url,
        'datetime': dt
    })
df = pd.DataFrame(data)

# %%
len(df)
# Out:
# 584

# %%
df.head()
# Out:
#      datetime                                           headline  \
# 0  1541520747  Erdogan Champions Khashoggi While Trampling Jo...
# 1  1541587767  Cameroon Students Have Been Released, Official...
# 2  1541584807  Dry Spell: Canada Runs Low on Legal Marijuana ...
# 3  1541529385  As Famine Looms in Yemen, Saudi-Led Coalition ...
# 4  1541474477  The Nauru Experience: Zero-Tolerance Immigrati...
#
#                                                  url
# 0  https://www.nytimes.com/2018/11/06/world/europ...
# 1  https://www.nytimes.com/2018/11/07/world/afric...
# 2  https://www.nytimes.com/2018/11/07/world/canad...
# 3  https://www.nytimes.com/2018/11/06/world/middl...
# 4  https://www.nytimes.com/2018/11/05/world/austr...

# %%
df.tail()
# Out:
#     datetime headline   url
# 579     None           None
# 580     None           None
# 581     None           None
# 582     None           None
# 583     None           None

# %%
df.to_csv('nyt_world.csv')

# %% [markdown]
# ## Epilogue

# %% [markdown]
# The `datetime` and `url` fields are wrong in the output CSV. `headline` seems alright. Nevertheless, we showed you that "human in the loop" is possible and how to scrape many pages by scrolling. One can try to analyse the page structure of new elements (after scroll) to find the solution.
